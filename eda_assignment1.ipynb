# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#

# %%
#creating dataframe

health_df= pd.read_csv('/content/heart_failure_clinical_records_dataset (1).csv')
health_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
health_df.info()
print('',health_df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB
# ...

# %%
health_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
health_df.isnull().sum()
print(health_df.corr())
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
# What is the distribution of age among heart failure patients in the dataset
sns.displot(health_df['age'])

# %%
#How does the death rate vary with age
sns.barplot(x=health_df['DEATH_EVENT'],y=health_df['age'])
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
# prompt: create a scatter plot of age and mark the death_event 1 in red I don' want any other column except age and death_event

import matplotlib.pyplot as plt
# Create a scatter plot of age and death_event
plt.figure(figsize=(8, 6))
plt.scatter(health_df[health_df['DEATH_EVENT'] == 0]['age'],
            health_df[health_df['DEATH_EVENT'] == 0]['DEATH_EVENT'],
            color='blue', label='No Death Event')
plt.scatter(health_df[health_df['DEATH_EVENT'] == 1]['age'],
            health_df[health_df['DEATH_EVENT'] == 1]['DEATH_EVENT'],
            color='red', label='Death Event')
plt.xlabel('Age')
plt.ylabel('DEATH_EVENT')
plt.title('Age vs. Death Event')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-bbf3351cd97c> in <cell line: 3>()
#       1 # prompt: create a scatter plot of age and mark the death_event 1 in red I don' want any other column except age and death_event
#       2
# ----> 3 sns.scatterplot(health_df['age'],hue=health_df['DEATH_EVENT'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     608 ):
#     609
# --> 610     p = _ScatterPlotter(
#     611         data=data,
#     612         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     389         )
#     390
# ...

# %%
# What is the percentage of male and female patients in the dataset?

male,female=health_df['sex'].value_counts()

male_percentage= (male/len(health_df))*100
female_percentage= (female/len(health_df))*100
print(f'male: {male_percentage}, female: {female_percentage}')
# Out:
# male: 64.88294314381271, female: 35.11705685618729

# %%
#How do5s th5 plat5l5t count vary among d"//5r5nt ag5 groups<
sns.lineplot(x=health_df['age'],y=health_df['platelets'])
#
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
#> Is there a corelation between creatinine_phosphokinase and serum_sodium level in the bloods
sns.heatmap(health_df.corr(),annot=True,cmap='coolwarm')
#
# Out:
# <Axes: >

# %%
# How does the prelevance of high blood pressure differ between male and female patient
sns.countplot(x=health_df['high_blood_pressure'],hue=health_df['sex'])
#
# Out:
# <Axes: xlabel='high_blood_pressure', ylabel='count'>

# %%
# what's the relationship between smoking habits and heart failuer
sns.countplot(x=health_df['DEATH_EVENT'],hue=health_df['smoking'])
#
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
sns.countplot(x=health_df['DEATH_EVENT'],hue=health_df['diabetes'])
#
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
sns.countplot(x=health_df['ejection_fraction'],hue=health_df['diabetes'])
#
# Out:
# <Axes: xlabel='ejection_fraction', ylabel='count'>

# %%
# prompt: # Are there any noticable paattern in the distribution of DEATH EVENT in different age group
# #

import matplotlib.pyplot as plt
# Create a box plot to visualize the distribution of DEATH_EVENT in different age groups
sns.boxplot(x='DEATH_EVENT', y='age', data=health_df)
plt.xlabel('Death Event')
plt.ylabel('Age')
plt.title('Distribution of Death Event in Different Age Groups')
plt.show()

# %%
sns.pairplot(health_df)
#

# %%
def kde(col):
  grid= sns.FacetGrid(health_df,hue= 'DEATH_EVENT',height =6, aspect=2)
  grid.map(sns.kdeplot,col)
  grid.add_legend()
  return grid

# %%
health_df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
kde('anaemia')

# %%
kde('age')

# %%
kde('creatinine_phosphokinase')

# %%
kde('diabetes')

# %%
# How does the serum creatine level vary between patient who survived and those who did not?
sns.boxplot(x=health_df['DEATH_EVENT'],y=health_df['creatinine_phosphokinase'])
#
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='creatinine_phosphokinase'>

# %%
from scipy import stats

no_diabetes = health_df[health_df['diabetes'] == 0]['ejection_fraction']
diabetes = health_df[health_df['diabetes'] == 1]['ejection_fraction']

# %%
t_stat,p_value= stats.ttest_ind(no_diabetes,diabetes)

# %%
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

if p_value < 0.05:
    print("There is a significant difference in ejection fraction between patients with and without diabetes.")
else:
    print("There is no significant difference in ejection fraction between patients with and without diabetes.")
# Out:
# T-statistic: 0.08358970647234736
# P-value: 0.9334389630426103
# There is no significant difference in ejection fraction between patients with and without diabetes.
